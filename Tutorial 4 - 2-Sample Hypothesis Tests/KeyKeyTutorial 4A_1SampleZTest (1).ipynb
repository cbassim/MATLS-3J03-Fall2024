# %% [markdown]
# # TUTORIAL 4 Pre-EXERCISE

# %% [markdown]
# ## PART 1
# ![image.png](attachment:98507000-9b08-4265-b3b7-87af86fc73b9.png)
#
# __What is the appropriate statistical test for this data?__

# %% [markdown]
# One sample Mean Z test.
#
# __Importing relevant libraries!__

# %%
import pandas as pd #library to work with data frames
import numpy as np #library to work with data frames
import matplotlib.pyplot as plt #library to plot figure
import matplotlib.dates as mdates #library for visualization
import seaborn as sns #library to plot figures
import scipy
from scipy import stats
from scipy.stats import t
import statsmodels.api as sm

# %% [markdown]
# ## PART 2
# __What assumptions are you making by choosing this test? Justify why they are acceptable.__
#
# Known population stanadrd deviation.  Sample from Normal population.

# %% [markdown]
# ## PART 3: Provide the 7 steps of the Procedures for Hypothesis Tests
# __1. Paramater of Interest__
#
# __2. State the null hypothesis__
#
# __3. State the null hypothesis__
#
# __4. Determine appropriate test statistic__
#
# __5. State the rejection criteria for null hypothesis__
#
# __6. Computations__
#
# __7. Draw Conclusions__

# %% [markdown]
# # Step 1: parameter of interest is mean buring rate = $\mu$
#
# mean of burning rate

# %% [markdown]
# # Step 2:  state the null hypothesis
#
# Is it a one-sided test or a two-sided test?
#
# two sided
#
# Null hypthesis= H0= $\mu1$=50
#
# Step 3: state the alternative hypothesis
#
# Alternative hypothesis - HA = $\mu1$ $\neq$ 50
#
# Step 4:  test statistic is:

# %% [markdown]
# The z statistic to test whether the mean is different than a population mean of 50 cm per sec
#
# ![image.png](attachment:cb970a85-337f-40a9-a3e0-7bbd0e4e1fa5.png)

# %% [markdown]
# Step 5:  Reject Ho if p-value less than 0.05.  The critical values at this alhpa value are z=
#
# ![image.png](attachment:f27191e4-0e2f-4d31-a8e7-917e926e08ea.png)

# %%
# critical value of z at alpha/2 = 0.025
stats.norm.ppf(0.025)
# Out:
# -1.9599639845400545

# %%
# critical value of Z at at alpha/2 = 0.975
stats.norm.ppf(0.975)
# Out:
# 1.959963984540054

# %% [markdown]
# Step 6 Computations
#
# ![image.png](attachment:cb35c06c-cd20-4864-b96d-1bbdaac59376.png)

# %%
# computation in python
z= (51.3-50) /(2/np.sqrt(25))
z
# Out:
# 3.249999999999993

# %% [markdown]
# Step 7:  Conclusions
#
# ![image.png](attachment:c2aa1e95-5bd6-4ba6-b36e-ed2938fcd2fb.png)
#
# Practical Interpretation: The mean burning rate differs from 50 centimeters per second, based on a sample of 25 measurements.

# %%
# look up in a z-table the p-value at z=3.25, or ask python for this as below
1-stats.norm.cdf(3.25)
# Out:
# 0.0005770250423907664

# %%
# multiply by 2 for 2-sided test
2* (1-stats.norm.cdf(3.25))
# Out:
# 0.0011540500847815327
